# %% [markdown]
# # Aprendendo notebooks
#
# Introdução ao uso de notebooks e da biblioteca pandas.

# %%
nome = 'Luciano'

print(nome)
# Out:
# Luciano

# %%
# Dicionários Python

aluno = {
    'nome':'Luciano',
    'matricula':'1234',
    'data_nascimento':'1993-09-05'
}

aluno2 = {
    'nome':'Cleitinho',
    'matricula':'5678',
    'data_nascimento':'2003-05-19'
}

print(aluno)
print(type(aluno))
print(aluno2['matricula'])
# Out:
# {'nome': 'Luciano', 'matricula': '1234', 'data_nascimento': '1993-09-05'}
# <class 'dict'>
# 5678

# %%
alunos = [{
    'nome':'Luciano',
    'matricula':'1234',
    'data_nascimento':'1993-09-05'
},

{
    'nome':'Cleitinho',
    'matricula':'5678',
    'data_nascimento':'2003-05-19'
}]

print(alunos[1]['nome'])
# Out:
# Cleitinho

# %%
frutas = [
{
    'nomes':['uva', 'laranja', 'maça', 'abacaxi'],
    'quantidade':[10, 15, 100, 0],
    'valor':[10.45, 5.49, 7.43, 5]
}
]

print(f'Fruta: {frutas[0]['nomes'][1]}, Quantidade: {frutas[0]['quantidade'][1]}, Valor: {frutas[0]['valor'][1]}')
# Out:
# Fruta: laranja, Quantidade: 15, Valor: 5.49

# %% [markdown]
# ## Instalando bibliotecas no Python
#
# Instala-se biblioteca python usando a estrutura:
#
# `pip install nome_biblioteca`

# %%
! pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 874.1 kB/s eta 0:00:11
#    -- ------------------------------------- 0.5/9.7 MB 874.1 kB/s eta 0:00:11
#    --- ------------------------------------ 0.8/9.7 MB 767.8 kB/s eta 0:00:12
#    --- ------------------------------------ 0.8/9.7 MB 767.8 kB/s eta 0:00:12
#    ---- ----------------------------------- 1.0/9.7 MB 739.4 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.7 MB 721.7 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.7 MB 721.7 kB/s eta 0:00:12
#    ------ --------------------------------- 1.6/9.7 MB 716.1 kB/s eta 0:00:12
# ...

# %%
import pandas as pd

# %%
frutas2 = ['uva', 'maça', 'laranja']

frutas3 = pd.Series(['uva', 'maça', 'laranja'])

print(type(frutas2))
print(type(frutas3))
# Out:
# <class 'list'>
# <class 'pandas.Series'>

# %%
# Serie (colunas)

display(frutas3)
# Out:
# 0        uva
# 1       maça
# 2    laranja
# dtype: str

# %%
# DataFrame

df = pd.DataFrame({
    'nome': ['uva', 'maça','laranja'],
    'quantidade': [10, 15, 20],
    'valor': [5.99, 3.50, 1.50],
    'data': ['2026-01-12','2026-02-06', '2025-03-15']
})

display(df)
# Out:
#       nome  quantidade  valor        data
# 0      uva          10   5.99  2026-01-12
# 1     maça          15   3.50  2026-02-06
# 2  laranja          20   1.50  2025-03-15

# %%
display(df['data'])
# Out:
# 0    2026-01-12
# 1    2026-02-06
# 2    2025-03-15
# Name: data, dtype: str
